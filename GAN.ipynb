# %%
### 라이브러리 및 데이터 불러오기
# 필요한 라이브러리를 불러온다.
import torch
import torch.nn as nn
from torch.optim import Adam
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable
import pickle

# 데이터 전처리 방식을 지정한다.
transform = transforms.Compose([
        transforms.ToTensor(), # 데이터를 PyTorch의 Tensor 형식으로 바꾼다.
        transforms.Normalize(mean=(0.5,), std=(0.5,)) # 픽셀값 0 ~ 1 -> -1 ~ 1
])

# MNIST 데이터셋을 불러온다. 지정한 폴더에 없을 경우 자동으로 다운로드한다.
mnist = datasets.MNIST(root='data', download=True, transform=transform)

# 데이터를 한번에 batch_size만큼만 가져오는 dataloader를 만든다.
dataloader = DataLoader(mnist, batch_size=60, shuffle=True)

# %%
import os
import imageio

if torch.cuda.is_available():
    use_gpu = True
leave_log = True
if leave_log:
    result_dir = 'GAN_generated_images'
    if not os.path.isdir(result_dir):
        os.mkdir(result_dir)

# %%
### GAN의 생성자(Generator)
# 생성자는 랜덤 벡터 z를 입력으로 받아 가짜 이미지를 출력한다.
class Generator(nn.Module):

    # 네트워크 구조
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(in_features=100, out_features=256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(in_features=256, out_features=512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(in_features=512, out_features=1024),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(in_features=1024, out_features=28*28),
            nn.Tanh())
    
    # (batch_size x 100) 크기의 랜덤 벡터를 받아 
    # 이미지를 (batch_size x 1 x 28 x 28) 크기로 출력한다.
    def forward(self, inputs):
        return self.main(inputs).view(-1, 1, 28, 28)

# %%
### GAN의 구분자(Discriminator)
# 구분자는 이미지를 입력으로 받아 이미지가 진짜인지 가짜인지 출력한다.
class Discriminator(nn.Module):
    
    # 네트워크 구조
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(in_features=28*28, out_features=1024),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(inplace=True),
            nn.Linear(in_features=1024, out_features=512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(inplace=True),
            nn.Linear(in_features=512, out_features=256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(inplace=True),
            nn.Linear(in_features=256, out_features=1),
            nn.Sigmoid())
    
    # (batch_size x 1 x 28 x 28) 크기의 이미지를 받아
    # 이미지가 진짜일 확률을 0~1 사이로 출력한다.
    def forward(self, inputs):
        inputs = inputs.view(-1, 28*28)
        return self.main(inputs)

# %%
### 생성자와 구분자 객체 만들기
G = Generator()
D = Discriminator()

if use_gpu:
    G.cuda()
    D.cuda()

# %%
### 손실 함수와 최적화 기법 지정하기
# Binary Cross Entropy loss
criterion = nn.BCELoss()

# 생성자의 매개 변수를 최적화하는 Adam optimizer
G_optimizer = Adam(G.parameters(), lr=0.0002, betas=(0.5, 0.999))
# 구분자의 매개 변수를 최적화하는 Adam optimizer
D_optimizer = Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %%
# 학습 결과 시각화하기
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

def square_plot(data, path):
    """Take an array of shape (n, height, width) or (n, height, width , 3)
       and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)"""

    if type(data) == list:
	    data = np.concatenate(data)
    # normalize data for display
    data = (data - data.min()) / (data.max() - data.min())

    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))

    padding = (((0, n ** 2 - data.shape[0]) ,
                (0, 1), (0, 1))  # add some space between filters
               + ((0, 0),) * (data.ndim - 3))  # don't pad the last dimension (if there is one)
    data = np.pad(data , padding, mode='constant' , constant_values=1)  # pad with ones (white)

    # tilethe filters into an image
    data = data.reshape((n , n) + data.shape[1:]).transpose((0 , 2 , 1 , 3) + tuple(range(4 , data.ndim + 1)))

    data = data.reshape((n * data.shape[1] , n * data.shape[3]) + data.shape[4:])

    plt.imsave(path, data, cmap='gray')

# %%
if leave_log:
    train_hist = {}
    train_hist['D_losses'] = []
    train_hist['G_losses'] = []
    generated_images = []
    
z_fixed = Variable(torch.randn(5 * 5, 100), volatile=True)
if use_gpu:
    z_fixed = z_fixed.cuda()

# %%
### 모델 학습을 위한 반복문
# 데이터셋을 100번 돌며 학습한다.
for epoch in range(100):
    
    if leave_log:
        D_losses = []
        G_losses = []
    
    # 한번에 batch_size만큼 데이터를 가져온다.
    for real_data, _ in dataloader:
        batch_size = real_data.size(0)
        
        # 데이터를 pytorch의 변수로 변환한다.
        real_data = Variable(real_data)

        ### 구분자 학습시키기

        # 이미지가 진짜일 때 정답 값은 1이고 가짜일 때는 0이다.
        # 정답지에 해당하는 변수를 만든다.
        target_real = Variable(torch.ones(batch_size, 1))
        target_fake = Variable(torch.zeros(batch_size, 1))
         
        if use_gpu:
            real_data, target_real, target_fake = real_data.cuda(), target_real.cuda(), target_fake.cuda()
            
        # 진짜 이미지를 구분자에 넣는다.
        D_result_from_real = D(real_data)
        # 구분자의 출력값이 정답지인 1에서 멀수록 loss가 높아진다.
        D_loss_real = criterion(D_result_from_real, target_real)

        # 생성자에 입력으로 줄 랜덤 벡터 z를 만든다.
        z = Variable(torch.randn((batch_size, 100)))
        
        if use_gpu:
            z = z.cuda()
            
        # 생성자로 가짜 이미지를 생성한다.
        fake_data = G(z)
        
        # 생성자가 만든 가짜 이미지를 구분자에 넣는다.
        D_result_from_fake = D(fake_data)
        # 구분자의 출력값이 정답지인 0에서 멀수록 loss가 높아진다.
        D_loss_fake = criterion(D_result_from_fake, target_fake)
        
        # 구분자의 loss는 두 문제에서 계산된 loss의 합이다.
        D_loss = D_loss_real + D_loss_fake
        
        # 구분자의 매개 변수의 미분값을 0으로 초기화한다.
        D.zero_grad()
        # 역전파를 통해 매개 변수의 loss에 대한 미분값을 계산한다.
        D_loss.backward()
        # 최적화 기법을 이용해 구분자의 매개 변수를 업데이트한다.
        D_optimizer.step()
        
        if leave_log:
            D_losses.append(D_loss.data[0])

        # train generator G

        ### 생성자 학습시키기
        
        # 생성자에 입력으로 줄 랜덤 벡터 z를 만든다.
        z = Variable(torch.randn((batch_size, 100)))
        
        if use_gpu:
            z = z.cuda()
        
        # 생성자로 가짜 이미지를 생성한다.
        fake_data = G(z)
        # 생성자가 만든 가짜 이미지를 구분자에 넣는다.
        D_result_from_fake = D(fake_data)
        # 생성자의 입장에서 구분자의 출력값이 1에서 멀수록 loss가 높아진다.
        G_loss = criterion(D_result_from_fake, target_real)
        
        # 생성자의 매개 변수의 미분값을 0으로 초기화한다.
        G.zero_grad()
        # 역전파를 통해 매개 변수의 loss에 대한 미분값을 계산한다.
        G_loss.backward()
        # 최적화 기법을 이용해 생성자의 매개 변수를 업데이트한다.
        G_optimizer.step()
        
        if leave_log:
            G_losses.append(G_loss.data[0])
    if leave_log:
        true_positive_rate = (D_result_from_real > 0.5).float().mean().data[0]
        true_negative_rate = (D_result_from_fake < 0.5).float().mean().data[0]
        base_message = ("Epoch: {epoch:<3d} D Loss: {d_loss:<8.6} G Loss: {g_loss:<8.6} "
                        "True Positive Rate: {tpr:<5.1%} True Negative Rate: {tnr:<5.1%}"
                       )
        message = base_message.format(
                    epoch=epoch,
                    d_loss=sum(D_losses)/len(D_losses),
                    g_loss=sum(G_losses)/len(G_losses),
                    tpr=true_positive_rate,
                    tnr=true_negative_rate
        )
        print(message)
    
    if leave_log:
        fake_data_fixed = G(z_fixed)
        image_path = result_dir + '/epoch{}.png'.format(epoch)
        square_plot(fake_data_fixed.view(25, 28, 28).cpu().data.numpy(), path=image_path)
        generated_images.append(image_path)
    
    if leave_log:
        train_hist['D_losses'].append(torch.mean(torch.FloatTensor(D_losses)))
        train_hist['G_losses'].append(torch.mean(torch.FloatTensor(G_losses)))

torch.save(G.state_dict(), "gan_generator.pkl")
torch.save(D.state_dict(), "gan_discriminator.pkl")
with open('gan_train_history.pkl', 'wb') as f:
    pickle.dump(train_hist, f)

generated_image_array = [imageio.imread(generated_image) for generated_image in generated_images]
imageio.mimsave(result_dir + '/GAN_generation.gif', generated_image_array, fps=5)
# Out:
# Epoch: 0   D Loss: 0.863213 G Loss: 2.02531  True Positive Rate: 80.0% True Negative Rate: 96.7%
# Epoch: 1   D Loss: 0.588318 G Loss: 2.8339   True Positive Rate: 90.0% True Negative Rate: 98.3%
# Epoch: 2   D Loss: 0.641012 G Loss: 2.36517  True Positive Rate: 83.3% True Negative Rate: 100.0%
# Epoch: 3   D Loss: 0.654862 G Loss: 2.14756  True Positive Rate: 85.0% True Negative Rate: 95.0%
# Epoch: 4   D Loss: 0.800644 G Loss: 1.77717  True Positive Rate: 68.3% True Negative Rate: 88.3%
# Epoch: 5   D Loss: 0.898469 G Loss: 1.55838  True Positive Rate: 88.3% True Negative Rate: 98.3%
# Epoch: 6   D Loss: 1.01998  G Loss: 1.29777  True Positive Rate: 66.7% True Negative Rate: 75.0%
# Epoch: 7   D Loss: 1.08073  G Loss: 1.17069  True Positive Rate: 76.7% True Negative Rate: 91.7%
# Epoch: 8   D Loss: 1.15293  G Loss: 1.06377  True Positive Rate: 66.7% True Negative Rate: 76.7%
# Epoch: 9   D Loss: 1.17763  G Loss: 1.0239   True Positive Rate: 58.3% True Negative Rate: 90.0%
# Epoch: 10  D Loss: 1.18642  G Loss: 1.00436  True Positive Rate: 51.7% True Negative Rate: 78.3%
# Epoch: 11  D Loss: 1.19234  G Loss: 0.998511 True Positive Rate: 55.0% True Negative Rate: 73.3%
# Epoch: 12  D Loss: 1.20263  G Loss: 0.979631 True Positive Rate: 61.7% True Negative Rate: 70.0%
# Epoch: 13  D Loss: 1.20182  G Loss: 0.977905 True Positive Rate: 43.3% True Negative Rate: 71.7%
# Epoch: 14  D Loss: 1.22249  G Loss: 0.950691 True Positive Rate: 70.0% True Negative Rate: 66.7%
# Epoch: 15  D Loss: 1.24068  G Loss: 0.923008 True Positive Rate: 60.0% True Negative Rate: 76.7%
# Epoch: 16  D Loss: 1.2506   G Loss: 0.905336 True Positive Rate: 56.7% True Negative Rate: 66.7%
# Epoch: 17  D Loss: 1.25427  G Loss: 0.907931 True Positive Rate: 65.0% True Negative Rate: 63.3%
# Epoch: 18  D Loss: 1.26299  G Loss: 0.89341  True Positive Rate: 50.0% True Negative Rate: 71.7%
# Epoch: 19  D Loss: 1.26346  G Loss: 0.887841 True Positive Rate: 51.7% True Negative Rate: 70.0%
# Epoch: 20  D Loss: 1.26776  G Loss: 0.884488 True Positive Rate: 58.3% True Negative Rate: 78.3%
# Epoch: 21  D Loss: 1.26183  G Loss: 0.890224 True Positive Rate: 51.7% True Negative Rate: 60.0%
# Epoch: 22  D Loss: 1.26986  G Loss: 0.87816  True Positive Rate: 68.3% True Negative Rate: 55.0%
# Epoch: 23  D Loss: 1.27067  G Loss: 0.877424 True Positive Rate: 55.0% True Negative Rate: 70.0%
# Epoch: 24  D Loss: 1.27121  G Loss: 0.878668 True Positive Rate: 73.3% True Negative Rate: 70.0%
# Epoch: 25  D Loss: 1.27081  G Loss: 0.877486 True Positive Rate: 53.3% True Negative Rate: 80.0%
# Epoch: 26  D Loss: 1.26598  G Loss: 0.884247 True Positive Rate: 60.0% True Negative Rate: 73.3%
# Epoch: 27  D Loss: 1.27128  G Loss: 0.878305 True Positive Rate: 53.3% True Negative Rate: 71.7%
# Epoch: 28  D Loss: 1.27847  G Loss: 0.865866 True Positive Rate: 55.0% True Negative Rate: 71.7%
# Epoch: 29  D Loss: 1.27558  G Loss: 0.871415 True Positive Rate: 65.0% True Negative Rate: 76.7%
# Epoch: 30  D Loss: 1.26968  G Loss: 0.881089 True Positive Rate: 60.0% True Negative Rate: 55.0%
# Epoch: 31  D Loss: 1.26832  G Loss: 0.885176 True Positive Rate: 66.7% True Negative Rate: 73.3%
# Epoch: 32  D Loss: 1.27113  G Loss: 0.879169 True Positive Rate: 50.0% True Negative Rate: 60.0%
# Epoch: 33  D Loss: 1.27026  G Loss: 0.885199 True Positive Rate: 58.3% True Negative Rate: 80.0%
# Epoch: 34  D Loss: 1.27038  G Loss: 0.87875  True Positive Rate: 66.7% True Negative Rate: 68.3%
# Epoch: 35  D Loss: 1.27052  G Loss: 0.879328 True Positive Rate: 46.7% True Negative Rate: 60.0%
# Epoch: 36  D Loss: 1.26955  G Loss: 0.885118 True Positive Rate: 58.3% True Negative Rate: 71.7%
# Epoch: 37  D Loss: 1.26334  G Loss: 0.895759 True Positive Rate: 51.7% True Negative Rate: 66.7%
# Epoch: 38  D Loss: 1.26675  G Loss: 0.88641  True Positive Rate: 61.7% True Negative Rate: 71.7%
# Epoch: 39  D Loss: 1.2734   G Loss: 0.877009 True Positive Rate: 55.0% True Negative Rate: 70.0%
# Epoch: 40  D Loss: 1.26453  G Loss: 0.887025 True Positive Rate: 60.0% True Negative Rate: 55.0%
# Epoch: 41  D Loss: 1.26503  G Loss: 0.886018 True Positive Rate: 53.3% True Negative Rate: 66.7%
# Epoch: 42  D Loss: 1.26548  G Loss: 0.889935 True Positive Rate: 70.0% True Negative Rate: 73.3%
# Epoch: 43  D Loss: 1.26924  G Loss: 0.882719 True Positive Rate: 66.7% True Negative Rate: 68.3%
# Epoch: 44  D Loss: 1.27167  G Loss: 0.88028  True Positive Rate: 63.3% True Negative Rate: 71.7%
# Epoch: 45  D Loss: 1.26691  G Loss: 0.887079 True Positive Rate: 56.7% True Negative Rate: 80.0%
# Epoch: 46  D Loss: 1.26559  G Loss: 0.891199 True Positive Rate: 61.7% True Negative Rate: 73.3%
# Epoch: 47  D Loss: 1.26742  G Loss: 0.886114 True Positive Rate: 56.7% True Negative Rate: 68.3%
# Epoch: 48  D Loss: 1.26816  G Loss: 0.890576 True Positive Rate: 61.7% True Negative Rate: 78.3%
# Epoch: 49  D Loss: 1.26476  G Loss: 0.890051 True Positive Rate: 45.0% True Negative Rate: 70.0%
# Epoch: 50  D Loss: 1.27259  G Loss: 0.878683 True Positive Rate: 65.0% True Negative Rate: 73.3%
# Epoch: 51  D Loss: 1.2676   G Loss: 0.887603 True Positive Rate: 55.0% True Negative Rate: 80.0%
# Epoch: 52  D Loss: 1.26999  G Loss: 0.884101 True Positive Rate: 66.7% True Negative Rate: 65.0%
# Epoch: 53  D Loss: 1.26571  G Loss: 0.885341 True Positive Rate: 51.7% True Negative Rate: 61.7%
# Epoch: 54  D Loss: 1.26892  G Loss: 0.883143 True Positive Rate: 60.0% True Negative Rate: 65.0%
# Epoch: 55  D Loss: 1.26653  G Loss: 0.885291 True Positive Rate: 58.3% True Negative Rate: 73.3%
# Epoch: 56  D Loss: 1.27076  G Loss: 0.879968 True Positive Rate: 55.0% True Negative Rate: 75.0%
# Epoch: 57  D Loss: 1.2662   G Loss: 0.888148 True Positive Rate: 61.7% True Negative Rate: 66.7%
# Epoch: 58  D Loss: 1.26939  G Loss: 0.885148 True Positive Rate: 68.3% True Negative Rate: 75.0%
# Epoch: 59  D Loss: 1.27361  G Loss: 0.878795 True Positive Rate: 55.0% True Negative Rate: 58.3%
# Epoch: 60  D Loss: 1.26921  G Loss: 0.882433 True Positive Rate: 65.0% True Negative Rate: 70.0%
# Epoch: 61  D Loss: 1.27305  G Loss: 0.879444 True Positive Rate: 61.7% True Negative Rate: 58.3%
# Epoch: 62  D Loss: 1.27762  G Loss: 0.87216  True Positive Rate: 66.7% True Negative Rate: 56.7%
# Epoch: 63  D Loss: 1.27427  G Loss: 0.878386 True Positive Rate: 68.3% True Negative Rate: 80.0%
# Epoch: 64  D Loss: 1.26874  G Loss: 0.880613 True Positive Rate: 61.7% True Negative Rate: 66.7%
# Epoch: 65  D Loss: 1.27218  G Loss: 0.878255 True Positive Rate: 61.7% True Negative Rate: 66.7%
# Epoch: 66  D Loss: 1.27247  G Loss: 0.879643 True Positive Rate: 55.0% True Negative Rate: 78.3%
# Epoch: 67  D Loss: 1.2731   G Loss: 0.877306 True Positive Rate: 60.0% True Negative Rate: 65.0%
# Epoch: 68  D Loss: 1.27055  G Loss: 0.882303 True Positive Rate: 50.0% True Negative Rate: 65.0%
# Epoch: 69  D Loss: 1.27522  G Loss: 0.874905 True Positive Rate: 75.0% True Negative Rate: 76.7%
# Epoch: 70  D Loss: 1.27238  G Loss: 0.880492 True Positive Rate: 50.0% True Negative Rate: 66.7%
# Epoch: 71  D Loss: 1.27514  G Loss: 0.874179 True Positive Rate: 60.0% True Negative Rate: 71.7%
# Epoch: 72  D Loss: 1.27622  G Loss: 0.871139 True Positive Rate: 58.3% True Negative Rate: 73.3%
# Epoch: 73  D Loss: 1.2775   G Loss: 0.874441 True Positive Rate: 56.7% True Negative Rate: 58.3%
# Epoch: 74  D Loss: 1.27772  G Loss: 0.873282 True Positive Rate: 58.3% True Negative Rate: 76.7%
# Epoch: 75  D Loss: 1.28074  G Loss: 0.865126 True Positive Rate: 60.0% True Negative Rate: 80.0%
# Epoch: 76  D Loss: 1.27559  G Loss: 0.877896 True Positive Rate: 60.0% True Negative Rate: 75.0%
# Epoch: 77  D Loss: 1.2708   G Loss: 0.878238 True Positive Rate: 50.0% True Negative Rate: 61.7%
# Epoch: 78  D Loss: 1.27641  G Loss: 0.87174  True Positive Rate: 63.3% True Negative Rate: 63.3%
# Epoch: 79  D Loss: 1.27915  G Loss: 0.868104 True Positive Rate: 63.3% True Negative Rate: 73.3%
# Epoch: 80  D Loss: 1.28017  G Loss: 0.867159 True Positive Rate: 58.3% True Negative Rate: 66.7%
# Epoch: 81  D Loss: 1.2784   G Loss: 0.86979  True Positive Rate: 66.7% True Negative Rate: 60.0%
# Epoch: 82  D Loss: 1.27558  G Loss: 0.870775 True Positive Rate: 61.7% True Negative Rate: 68.3%
# Epoch: 83  D Loss: 1.2754   G Loss: 0.873937 True Positive Rate: 63.3% True Negative Rate: 71.7%
# Epoch: 84  D Loss: 1.2752   G Loss: 0.873828 True Positive Rate: 38.3% True Negative Rate: 63.3%
# Epoch: 85  D Loss: 1.27848  G Loss: 0.86645  True Positive Rate: 56.7% True Negative Rate: 58.3%
# Epoch: 86  D Loss: 1.27695  G Loss: 0.870793 True Positive Rate: 60.0% True Negative Rate: 78.3%
# Epoch: 87  D Loss: 1.28143  G Loss: 0.865612 True Positive Rate: 46.7% True Negative Rate: 71.7%
# Epoch: 88  D Loss: 1.27984  G Loss: 0.868262 True Positive Rate: 38.3% True Negative Rate: 53.3%
# Epoch: 89  D Loss: 1.27558  G Loss: 0.870339 True Positive Rate: 76.7% True Negative Rate: 71.7%
# Epoch: 90  D Loss: 1.28778  G Loss: 0.856272 True Positive Rate: 51.7% True Negative Rate: 68.3%
# Epoch: 91  D Loss: 1.27999  G Loss: 0.867708 True Positive Rate: 43.3% True Negative Rate: 80.0%
# Epoch: 92  D Loss: 1.27956  G Loss: 0.866868 True Positive Rate: 61.7% True Negative Rate: 78.3%
# Epoch: 93  D Loss: 1.27606  G Loss: 0.867709 True Positive Rate: 60.0% True Negative Rate: 71.7%
# Epoch: 94  D Loss: 1.27712  G Loss: 0.872978 True Positive Rate: 60.0% True Negative Rate: 70.0%
# Epoch: 95  D Loss: 1.28076  G Loss: 0.865007 True Positive Rate: 51.7% True Negative Rate: 68.3%
# Epoch: 96  D Loss: 1.28044  G Loss: 0.863879 True Positive Rate: 58.3% True Negative Rate: 68.3%
# Epoch: 97  D Loss: 1.28307  G Loss: 0.860898 True Positive Rate: 61.7% True Negative Rate: 68.3%
# Epoch: 98  D Loss: 1.28338  G Loss: 0.864145 True Positive Rate: 61.7% True Negative Rate: 58.3%
# Epoch: 99  D Loss: 1.28162  G Loss: 0.870137 True Positive Rate: 45.0% True Negative Rate: 68.3%
